# %%
import pandas as pd
import nfl_data_py as nfl

# %%
# Get the current season's schedule
schedule = nfl.import_schedules([2024])

# %%
schedule.shape
# Out:
# (272, 46)

# %%
schedule.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'gameday', 'weekday',
#        'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
#        'location', 'result', 'total', 'overtime', 'old_game_id', 'gsis',
#        'nfl_detail_id', 'pfr', 'pff', 'espn', 'ftn', 'away_rest', 'home_rest',
#        'away_moneyline', 'home_moneyline', 'spread_line', 'away_spread_odds',
#        'home_spread_odds', 'total_line', 'under_odds', 'over_odds', 'div_game',
#        'roof', 'surface', 'temp', 'wind', 'away_qb_id', 'home_qb_id',
#        'away_qb_name', 'home_qb_name', 'away_coach', 'home_coach', 'referee',
#        'stadium_id', 'stadium'],
#       dtype='object')

# %%
pd.options.display.max_columns = None
schedule.head(3)
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 6706   2024_01_BAL_KC    2024       REG     1  2024-09-05  Thursday    20:20
# 6707   2024_01_GB_PHI    2024       REG     1  2024-09-06    Friday    20:15
# 6708  2024_01_PIT_ATL    2024       REG     1  2024-09-08    Sunday    13:00
#
#      away_team  away_score home_team  home_score location  result  total  \
# 6706       BAL        20.0        KC        27.0     Home     7.0   47.0
# 6707        GB        29.0       PHI        34.0  Neutral     5.0   63.0
# 6708       PIT        18.0       ATL        10.0     Home    -8.0   28.0
#
#       overtime  old_game_id   gsis nfl_detail_id           pfr  pff  \
# 6706       0.0   2024090500  59508           NaN  202409050kan  NaN
# 6707       0.0   2024090600  59509           NaN  202409060phi  NaN
# 6708       0.0   2024090800  59510           NaN  202409080atl  NaN
#
#            espn     ftn  away_rest  home_rest  away_moneyline  home_moneyline  \
# ...

# %%
schedule['weekday']
# Out:
# 6706    Thursday
# 6707      Friday
# 6708      Sunday
# 6709      Sunday
# 6710      Sunday
#           ...
# 6973      Sunday
# 6974      Sunday
# 6975      Sunday
# 6976      Sunday
# 6977      Sunday
# Name: weekday, Length: 272, dtype: object

# %%
weekday_map = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
schedule['day_of_week'] = schedule['weekday'].map(weekday_map)

# %%
schedule['gameday'] = pd.to_datetime(schedule['gameday'])
schedule['month'] = schedule['gameday'].dt.month

# %%
season_24_games = schedule[['home_team','away_team','season','month','week','day_of_week']].reset_index(drop = 'index')

# %%
season_24_games
# Out:
#     home_team away_team  season  month  week  day_of_week
# 0          KC       BAL    2024      9     1            3
# 1         PHI        GB    2024      9     1            4
# 2         ATL       PIT    2024      9     1            6
# 3         BUF       ARI    2024      9     1            6
# 4         CHI       TEN    2024      9     1            6
# ..        ...       ...     ...    ...   ...          ...
# 267       NYJ       MIA    2024      1    18            6
# 268       PHI       NYG    2024      1    18            6
# 269       PIT       CIN    2024      1    18            6
# 270        TB        NO    2024      1    18            6
# 271       TEN       HOU    2024      1    18            6
#
# [272 rows x 6 columns]

# %%
season_24_games= pd.read_csv('NFL_2024_schedule.csv')

# %%
nfl_teams = {
    'ARI': 'Arizona Cardinals',
    'ATL': 'Atlanta Falcons',
    'BAL': 'Baltimore Ravens',
    'BUF': 'Buffalo Bills',
    'CAR': 'Carolina Panthers',
    'CHI': 'Chicago Bears',
    'CIN': 'Cincinnati Bengals',
    'CLE': 'Cleveland Browns',
    'DAL': 'Dallas Cowboys',
    'DEN': 'Denver Broncos',
    'DET': 'Detroit Lions',
    'GB': 'Green Bay Packers',
    'HOU': 'Houston Texans',
    'IND': 'Indianapolis Colts',
    'JAX': 'Jacksonville Jaguars',
    'KC': 'Kansas City Chiefs',
    'LA': 'Los Angeles Rams',
    'LAC': 'Los Angeles Chargers',
    'LV': 'Las Vegas Raiders',
    'MIA': 'Miami Dolphins',
    'MIN': 'Minnesota Vikings',
    'NE': 'New England Patriots',
    'NO': 'New Orleans Saints',
    'NYG': 'New York Giants',
    'NYJ': 'New York Jets',
    'PHI': 'Philadelphia Eagles',
    'PIT': 'Pittsburgh Steelers',
    'SEA': 'Seattle Seahawks',
    'SF': 'San Francisco 49ers',
    'TB': 'Tampa Bay Buccaneers',
    'TEN': 'Tennessee Titans',
    'WAS': 'Washington Commanders'
}

season_24_games['home_team'] = season_24_games['home_team'].map(nfl_teams)
season_24_games['away_team'] = season_24_games['away_team'].map(nfl_teams)

# %%
season_24_games
# Out:
#                 home_team            away_team  season  month  week  \
# 0      Kansas City Chiefs     Baltimore Ravens    2024      9     1
# 1     Philadelphia Eagles    Green Bay Packers    2024      9     1
# 2         Atlanta Falcons  Pittsburgh Steelers    2024      9     1
# 3           Buffalo Bills    Arizona Cardinals    2024      9     1
# 4           Chicago Bears     Tennessee Titans    2024      9     1
# ..                    ...                  ...     ...    ...   ...
# 267         New York Jets       Miami Dolphins    2024      1    18
# 268   Philadelphia Eagles      New York Giants    2024      1    18
# 269   Pittsburgh Steelers   Cincinnati Bengals    2024      1    18
# 270  Tampa Bay Buccaneers   New Orleans Saints    2024      1    18
# 271      Tennessee Titans       Houston Texans    2024      1    18
#
#      day_of_week
# 0              3
# 1              4
# 2              6
# 3              6
# 4              6
# ..           ...
# 267            6
# ...

# %%
season_24_games.to_csv('NFL_2024_schedule.csv', index = False)
