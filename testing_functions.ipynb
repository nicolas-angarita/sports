# %%
import pandas as pd
import wrangle as w

import warnings
warnings.filterwarnings('ignore')

# %%
season_2024 = w.nfl_data_scrape()
season_2024
# Out:
# Enter the first year of the season you want to collect data from:  2024
# Enter the last year of the season you want to collect data from:  2024
# Enter a filename for this data to save as a csv file (no need to add extenison of file):  testing_file
# Number Of Seasons = 1
# Number Of Teams = 32
# Processing NFL Seasons: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [04:23<00:00,  8.23s/Season]
# Data will be saved as: testing_file.csv
#     season team  Week  Day          Date Unnamed: 3 Unnamed: 4   OT  \
# 0     2024  CRD     1  Sun   September 8   boxscore          L  NaN
# 1     2024  CRD     2  Sun  September 15   boxscore          W  NaN
# 2     2024  CRD     3  Sun  September 22   boxscore          L  NaN
# 3     2024  CRD     4  Sun  September 29   boxscore          L  NaN
# 4     2024  CRD     5  Sun     October 6   boxscore          W  NaN
# ...

# %%
clean_data = w.clean_data('nfl_data_2024_season_raw_data.csv')
clean_data.head(3)
# Out:
#    season team  week  day          date result   ot  host               opp  \
# 0    2024  CRD     1  Sun   September 8      L   no  away     Buffalo Bills
# 1    2024  CRD     2  Sun  September 15      W   no  home  Los Angeles Rams
# 2    2024  CRD     3  Sun  September 22      L   no  home     Detroit Lions
#
#     pts  ...  fga_opp  xpm_opp  xpa_opp  pnt_opp  punt_yds_opp  3dconv_opp  \
# 0  28.0  ...      2.0      4.0      4.0      2.0          85.0         3.0
# 1  41.0  ...      1.0      1.0      1.0      4.0         215.0         2.0
# 2  13.0  ...      0.0      2.0      3.0      5.0         247.0         6.0
#
#    3datt_opp  4dconv_opp  4datt_opp  top_opp
# 0        9.0         2.0        2.0    30:30
# 1       11.0         1.0        3.0    23:06
# 2       12.0         0.0        1.0    36:49
#
# [3 rows x 63 columns]

# %%
df = w.final_cleaned_df(clean_data)

# %%
df.head(3)
# Out:
#                                         game_id            home_team  \
# 0    2024_1_Kansas City Chiefs_Baltimore Ravens   Kansas City Chiefs
# 1  2024_1_Philadelphia Eagles_Green Bay Packers  Philadelphia Eagles
# 2   2024_1_New Orleans Saints_Carolina Panthers   New Orleans Saints
#
#            away_team       date  season  month  week  day_of_week  overtime  \
# 0   Baltimore Ravens 2024-09-05    2024      9     1            3         0
# 1  Green Bay Packers 2024-09-06    2024      9     1            4         0
# 2  Carolina Panthers 2024-09-08    2024      9     1            6         0
#
#    home_pts  ...  away_4datt  home_top  away_top  pts_diff_home  \
# 0      27.0  ...         2.0      1577      2023            7.0
# 1      34.0  ...         1.0      1967      1633            5.0
# 2      47.0  ...         3.0      2199      1401           37.0
#
#    pass_yds_diff_home  rush_yds_diff_home  top_diff_home  home_total_yds  \
# ...

# %%
df.shape
# Out:
# (272, 70)

# %%
old_data = pd.read_csv('nfl_data_2000_2023_seasons.csv', parse_dates=['date'], date_format='%Y-%m-%d')

# %%
old_data.head(3)
# Out:
#                                             game_id             home_team  \
# 0          2000_1_New York Giants_Arizona Cardinals       New York Giants
# 1  2000_1_New England Patriots_Tampa Bay Buccaneers  New England Patriots
# 2       2000_1_Pittsburgh Steelers_Baltimore Ravens   Pittsburgh Steelers
#
#               away_team       date  season  month  week  day_of_week  \
# 0     Arizona Cardinals 2000-09-03    2000      9     1            6
# 1  Tampa Bay Buccaneers 2000-09-03    2000      9     1            6
# 2      Baltimore Ravens 2000-09-03    2000      9     1            6
#
#    overtime  home_pts  ...  away_4datt  home_top  away_top  pts_diff_home  \
# 0         0        21  ...           2      1890      1710              5
# 1         0        16  ...           0      1705      1895             -5
# 2         0         0  ...           1      1493      2107            -16
#
#    pass_yds_diff_home  rush_yds_diff_home  top_diff_home  home_total_yds  \
# ...

# %%
old_data.shape
# Out:
# (6175, 70)

# %%
old_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                6175 non-null   object
#  1   home_team              6175 non-null   object
#  2   away_team              6175 non-null   object
#  3   date                   6175 non-null   datetime64[ns]
#  4   season                 6175 non-null   int64
#  5   month                  6175 non-null   int64
#  6   week                   6175 non-null   int64
#  7   day_of_week            6175 non-null   int64
#  8   overtime               6175 non-null   int64
#  9   home_pts               6175 non-null   int64
#  10  away_pts               6175 non-null   int64
#  11  home_pass_cmp          6175 non-null   int64
#  12  away_pass_cmp          6175 non-null   int64
#  13  home_pass_att          6175 non-null   int64
# ...
